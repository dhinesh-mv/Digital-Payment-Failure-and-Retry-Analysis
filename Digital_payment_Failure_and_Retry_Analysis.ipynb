# %%
# Import dataset
# Read Excel file

import pandas as pd

df = pd.read_excel("Digital_payment_Failure_and_Retry_behaviour.xlsx")

df
# Out:
#        transaction_id  user_id transaction_date payment_method bank_name  \
# 0                 166     1206       2024-07-02    Credit Card      AXIS
# 1                 375     6699       2024-10-23    Credit Card     ICICI
# 2                1077     7376       2024-06-14    Credit Card     ICICI
# 3                1259     2619       2024-06-28    Credit Card      AXIS
# 4                1358     6373       2024-11-21    Credit Card      HDFC
# ...               ...      ...              ...            ...       ...
# 49995           48523     6066       2024-06-05         Wallet      HDFC
# 49996           49143     5827       2024-08-21    Credit Card      HDFC
# 49997           49416     9982       2024-02-13    Credit Card      AXIS
# 49998           49494     5666       2024-05-06     Debit Card       SBI
# 49999           49523    14466       2024-07-22    Credit Card       SBI
#
#       merchant_category  transaction_amount device_type network_type  \
# ...

# %%
# Data Understanding

df.shape
# Out:
# (50000, 22)

# %%
df.columns
# Out:
# Index(['transaction_id', 'user_id', 'transaction_date', 'payment_method',
#        'bank_name', 'merchant_category', 'transaction_amount', 'device_type',
#        'network_type', 'transaction_status', 'failure_reason',
#        'retry_attempted', 'retry_count', 'retry_success', 'user_location',
#        'merchant_id', 'upi_app', 'transaction_day_of_week',
#        'transaction_month', 'is_weekend', 'transaction_amount_category',
#        'delivery_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   transaction_id               50000 non-null  int64
#  1   user_id                      50000 non-null  int64
#  2   transaction_date             50000 non-null  datetime64[ns]
#  3   payment_method               50000 non-null  object
#  4   bank_name                    50000 non-null  object
#  5   merchant_category            50000 non-null  object
#  6   transaction_amount           50000 non-null  float64
#  7   device_type                  50000 non-null  object
#  8   network_type                 50000 non-null  object
#  9   transaction_status           50000 non-null  object
#  10  failure_reason               50000 non-null  object
#  11  retry_attempted              50000 non-null  object
# ...

# %%
df.describe()
# Out:
#        transaction_id       user_id               transaction_date  \
# count    50000.000000  50000.000000                          50000
# mean     25000.500000   8009.185640  2024-07-01 03:11:46.752000256
# min          1.000000   1000.000000            2024-01-01 00:00:00
# 25%      12500.750000   4491.750000            2024-04-01 00:00:00
# 50%      25000.500000   8014.000000            2024-07-02 00:00:00
# 75%      37500.250000  11541.000000            2024-09-30 00:00:00
# max      50000.000000  14999.000000            2024-12-30 00:00:00
# std      14433.901067   4050.794294                            NaN
#
#        transaction_amount   retry_count   merchant_id  transaction_month  \
# count        50000.000000  50000.000000  50000.000000        50000.00000
# mean         25083.319141      0.271520   2598.164880            6.50468
# min             10.110000      0.000000    200.000000            1.00000
# ...

# %%
df.dtypes
# Out:
# transaction_id                          int64
# user_id                                 int64
# transaction_date               datetime64[ns]
# payment_method                         object
# bank_name                              object
# merchant_category                      object
# transaction_amount                    float64
# device_type                            object
# network_type                           object
# transaction_status                     object
# failure_reason                         object
# retry_attempted                        object
# retry_count                             int64
# retry_success                          object
# user_location                          object
# merchant_id                             int64
# upi_app                                object
# transaction_day_of_week                object
# transaction_month                       int64
# is_weekend                               bool
# ...

# %%
# Data Cleaning
# Missing Values

df.isnull().sum()
# Out:
# transaction_id                 0
# user_id                        0
# transaction_date               0
# payment_method                 0
# bank_name                      0
# merchant_category              0
# transaction_amount             0
# device_type                    0
# network_type                   0
# transaction_status             0
# failure_reason                 0
# retry_attempted                0
# retry_count                    0
# retry_success                  0
# user_location                  0
# merchant_id                    0
# upi_app                        0
# transaction_day_of_week        0
# transaction_month              0
# is_weekend                     0
# transaction_amount_category    0
# delivery_date                  0
# dtype: int64

# %%
# Duplicate Values

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Wrong Datatypes

df['transaction_date']=pd.to_datetime(df['transaction_date'])

# %%
# Outlier Detection

import matplotlib.pyplot as plt

plt.boxplot(df['transaction_amount'])
plt.show()

# %%
# Exploratory Data Analysis (EDA)
# Total Transactions

len(df)
# Out:
# 50000

# %%
# Success vs Failure

df['transaction_status'].value_counts()
# Out:
# transaction_status
# Success    41011
# Failed      8989
# Name: count, dtype: int64

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# Credit Card    10078
# UPI            10028
# Net Banking     9995
# Debit Card      9970
# Wallet          9929
# Name: count, dtype: int64

# %%
df['bank_name'].value_counts()
# Out:
# bank_name
# HDFC     10166
# PNB      10073
# AXIS      9976
# ICICI     9972
# SBI       9813
# Name: count, dtype: int64

# %%
df['merchant_category'].value_counts()
# Out:
# merchant_category
# E-commerce    10134
# Travel        10052
# Shopping       9974
# Recharge       9932
# Food           9908
# Name: count, dtype: int64

# %%
df['merchant_category'].value_counts()
# Out:
# merchant_category
# E-commerce    10134
# Travel        10052
# Shopping       9974
# Recharge       9932
# Food           9908
# Name: count, dtype: int64

# %%
df['merchant_category'].value_counts()
# Out:
# merchant_category
# E-commerce    10134
# Travel        10052
# Shopping       9974
# Recharge       9932
# Food           9908
# Name: count, dtype: int64

# %%
df['retry_attempted'].value_counts()
# Out:
# retry_attempted
# No     45069
# Yes     4931
# Name: count, dtype: int64

# %%
df['retry_success'].value_counts()
# Out:
# retry_success
# Not Applicable    42003
# No                 4816
# Yes                3181
# Name: count, dtype: int64

# %%
df['transaction_amount'].describe()
# Out:
# count    50000.000000
# mean     25083.319141
# std      14424.141716
# min         10.110000
# 25%      12652.630000
# 50%      25039.805000
# 75%      37531.835000
# max      49996.490000
# Name: transaction_amount, dtype: float64

# %%
# Monthly Transactions

df.groupby('transaction_month')['transaction_amount'].sum()
# Out:
# transaction_month
# 1     1.066107e+08
# 2     9.930943e+07
# 3     1.053798e+08
# 4     1.032225e+08
# 5     1.053580e+08
# 6     1.022792e+08
# 7     1.060693e+08
# 8     1.105237e+08
# 9     1.037562e+08
# 10    1.069339e+08
# 11    1.007819e+08
# 12    1.039411e+08
# Name: transaction_amount, dtype: float64

# %%
# Day Wise Transactions

df.groupby('transaction_day_of_week')['transaction_amount'].sum()
# Out:
# transaction_day_of_week
# Friday       1.768185e+08
# Monday       1.821187e+08
# Saturday     1.823278e+08
# Sunday       1.782873e+08
# Thursday     1.752926e+08
# Tuesday      1.791698e+08
# Wednesday    1.801513e+08
# Name: transaction_amount, dtype: float64

# %%
# Weekend Analysis

df.groupby('is_weekend')['transaction_status'].count()
# Out:
# is_weekend
# False    35640
# True     14360
# Name: transaction_status, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Transaction Status Distribution (Bar Chart)

plt.figure(figsize=(6,4))
sns.countplot(x='transaction_status', data=df)
plt.title("Transaction Status Distribution")
plt.xlabel("Transaction Status")
plt.ylabel("Count")
plt.show()

# %%
# Payment Method Distribution (Bar Chart)

plt.figure(figsize=(8,5))
sns.countplot(x='payment_method', data=df)
plt.title("Payment Method Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y='failure_reason', data=df)
plt.title("Failure Reasons")
plt.show()
